# %%
import plotly.offline as pyo
import plotly.graph_objs as go
import plotly.figure_factory as ff
import pandas as pd
import numpy as np

df=pd.read_csv(r'C:\Users\rodrigo.villanueva.c\Documents\TODO_PYTHON\Curso_Ploty-dash\Datasets\3.11\PEATONES_2020_mod.csv', encoding='ISO-8859-1', delimiter=';')

df.head(10)
# Out:
#         FECHA     HORA    IDENTIFICADOR  PEATONES  NÚMERO_DISTRITO DISTRITO  \
# 0  01/01/2020  0:00:00  PERM_PEA02_PM01       497              1.0   Centro
# 1  01/01/2020  0:15:00  PERM_PEA02_PM01       244              1.0   Centro
# 2  01/01/2020  0:30:00  PERM_PEA02_PM01       179              1.0   Centro
# 3  01/01/2020  0:45:00  PERM_PEA02_PM01       174              1.0   Centro
# 4  01/01/2020  1:00:00  PERM_PEA02_PM01       131              1.0   Centro
# 5  01/01/2020  1:15:00  PERM_PEA02_PM01        95              1.0   Centro
# 6  01/01/2020  1:45:00  PERM_PEA02_PM01       175              1.0   Centro
# 7  01/01/2020  2:00:00  PERM_PEA02_PM01       149              1.0   Centro
# 8  01/01/2020  2:15:00  PERM_PEA02_PM01       126              1.0   Centro
# 9  01/01/2020  2:30:00  PERM_PEA02_PM01       107              1.0   Centro
#
#         NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL         OBSERVACIONES_DIRECCION  \
# ...

# %%
#Primera pregunta
#hist_data=[df["PEATONES"]]
#group_labels=["Tráfico Peatonal"]

#segunda Pregunta
dat1=df[df["DISTRITO"]=="Arganzuela"]["PEATONES"]
dat2=df[df["DISTRITO"]=="Centro"]["PEATONES"]
hist_data=[dat1,dat2]
group_labels=["Arganzuela","Centro"]


fig=ff.create_distplot(hist_data,group_labels,bin_size=10)

pyo.plot(fig,filename="Eje_Displot1.html")
# Out:
# 'Eje_Displot1.html'
